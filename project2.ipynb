# %% [markdown]
# # Project 2: Web Scraping and API access

# %%
# !pip install beautifulsoup4

# %% [markdown]
# ## Part 1: Explore the html for Wikipedia articles.

# %% [markdown]
# ### A. Using inspect element, copy the html code for a table.

# %% [markdown]
# <table class="wikitable" style="text-align:center; float:left; font-size:90%; margin:10px">
# <caption>Freshmen admitted in Fall 2023
# <sup id="cite_ref-64" class="reference"><a href="#cite_note-64"><span class="cite-bracket">[</span>63<span class="cite-bracket">]</span></a></sup>
# <sup id="cite_ref-Admit_rates_52-1" class="reference"><a href="#cite_note-Admit_rates-52"><span class="cite-bracket">[</span>51<span class="cite-bracket">]</span></a></sup>
# </caption>
# <tbody><tr>
# <th>College
# </th>
# <th>ACT composite*<br><small>(middle 50%, out of 36)</small>
# </th>
# <th>SAT composite*<br><small>(middle 50%, out of 1600)</small>
# </th>
# <th>Admit rate
# </th>
# <th>Computer Science Programs<sup id="cite_ref-Admit_rates_52-2" class="reference"><a href="#cite_note-Admit_rates-52"><span class="cite-bracket">[</span>51<span class="cite-bracket">]</span></a></sup><sup id="cite_ref-65" class="reference"><a href="#cite_note-65"><span class="cite-bracket">[</span>64<span class="cite-bracket">]</span></a></sup>
# </th></tr>
# <tr>
# <th>Grainger College of Engineering
# </th>
# <td>33–35
# </td>
# <td>1470–1550
# </td>
# <td>22.3%
# </td>
# <td>Computer Science admit rate: 7.5%<br>
# <p>Computer Science + X admit rate: 19.6%
# </p>
# </td></tr>
# <tr>
# <th>College of Liberal Arts &amp; Sciences
# </th>
# <td>31–34
# </td>
# <td>1400–1530
# </td>
# <td>45.5%
# </td>
# <td>
# </td></tr>
# <tr>
# <th>Gies College of Business
# </th>
# <td>31–34
# </td>
# <td>1420–1510
# </td>
# <td>24.2%
# </td>
# <td>
# </td></tr>
# <tr>
# <th>School of Information Sciences
# </th>
# <td>33–35
# </td>
# <td>1460–1540
# </td>
# <td>21.6%
# </td></tr>
# <tr>
# <th>School of Social Work
# </th>
# <td>27–28
# </td>
# <td>1160–1345
# </td>
# <td>37.4%
# </td>
# <td>
# </td></tr>
# </tbody></table>

# %% [markdown]
# ### B. Using inspect element, find the html syntax for a link.

# %% [markdown]
# <a href="/wiki/The_Chicago_Tribune" class="mw-redirect" title="The Chicago Tribune">The Chicago Tribune</a>

# %% [markdown]
# ### C. Using inspect element, find the html syntax for linking an image

# %% [markdown]
# <img src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/GreenStreetCampustownChampaignIllinois.JPG/220px-GreenStreetCampustownChampaignIllinois.JPG" decoding="async" width="220" height="147" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/GreenStreetCampustownChampaignIllinois.JPG/330px-GreenStreetCampustownChampaignIllinois.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/GreenStreetCampustownChampaignIllinois.JPG/440px-GreenStreetCampustownChampaignIllinois.JPG 2x" data-file-width="5184" data-file-height="3456">

# %% [markdown]
# ## Part 2: Explore one Wikipedia page with the beautifulsoup package

# %%
import bs4
import requests
import pandas as pd

# %%
#save and print the text content of a page with all tags removed

url = "https://en.wikipedia.org/wiki/BTS"
source = requests.get(url).text
soup = bs4.BeautifulSoup(source)
print(soup.get_text())
# Out:
# BTS - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
#  Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Name
#
#
#
#
#
#
#
#
# 2
# History
#
#
#
#
# Toggle History subsection
#
#
#
#
#
# 2.1
# 2010–2014: Formation and early years
#
#
#
#
#
#
#
#
# 2.2
# ...

# %%
#download an image with beautifulsoup and save it in this repository

img_tags = soup.find_all('img')
img_tags[1]['src']
# Out:
# '/static/images/mobile/copyright/wikipedia-wordmark-en.svg'

# %%
img_url = img_tags[0]['src']
img_url = "https://en.wikipedia.org/wiki/BTS" + img_url
img = requests.get(img_url)

# %%
with open('bts.jpg', 'wb') as f:
    f.write(img.content)

# %%
#find all the links in a page with beautifulsoup
#print the first 100 characters of ten of these links

# %%
links = soup.find_all('a')
link_url = []
for i in links:
    try:
        link_url.append(i['href'])
    except:
        continue
print(link_url)
# Out:
# ['#bodyContent', '/wiki/Main_Page', '/wiki/Wikipedia:Contents', '/wiki/Portal:Current_events', '/wiki/Special:Random', '/wiki/Wikipedia:About', '//en.wikipedia.org/wiki/Wikipedia:Contact_us', '/wiki/Help:Contents', '/wiki/Help:Introduction', '/wiki/Wikipedia:Community_portal', '/wiki/Special:RecentChanges', '/wiki/Wikipedia:File_upload_wizard', '/wiki/Main_Page', '/wiki/Special:Search', 'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en', '/w/index.php?title=Special:CreateAccount&returnto=Wikipedia%3ACommunity+portal', '/w/index.php?title=Special:UserLogin&returnto=Wikipedia%3ACommunity+portal', '/w/index.php?title=Special:CreateAccount&returnto=Wikipedia%3ACommunity+portal', '/w/index.php?title=Special:UserLogin&returnto=Wikipedia%3ACommunity+portal', '/wiki/Help:Introduction', '/wiki/Special:MyContributions', '/wiki/Special:MyTalk', 'https://ady.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# ...

# %%
link_url = [i if 'http' in i else 'https://wikipedia.org' + i for i in link_url][:10]

# %%
link_url
# Out:
# ['https://wikipedia.org#bodyContent',
#  'https://wikipedia.org/wiki/Main_Page',
#  'https://wikipedia.org/wiki/Wikipedia:Contents',
#  'https://wikipedia.org/wiki/Portal:Current_events',
#  'https://wikipedia.org/wiki/Special:Random',
#  'https://wikipedia.org/wiki/Wikipedia:About',
#  'https://wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://wikipedia.org/wiki/Help:Contents',
#  'https://wikipedia.org/wiki/Help:Introduction',
#  'https://wikipedia.org/wiki/Wikipedia:Community_portal']

# %%
def clean(text):
    text = text.lower()
    text = ''.join([char for char in text if char.isalpha() or char == ' '])
    text = ' '.join(text.split())
    return text

# %%
link_text = []
title = []
count = 0
for i in link_url:
    try:
        source = requests.get(i).text
        soup = bs4.BeautifulSoup(source)
        title.append(clean(soup.title.text))
        link_text.append(clean(soup.text))
        count += 1
        if count == 10:
            break
    except:
        continue
df = pd.DataFrame({'title': title, 'text': link_text})

# %%
df
# Out:
#                                  title  \
# 0                            wikipedia
# 1      wikipedia the free encyclopedia
# 2          wikipediacontents wikipedia
# 3       portalcurrent events wikipedia
# 4                  gulomahda wikipedia
# 5             wikipediaabout wikipedia
# 6                            not found
# 7               helpcontents wikipedia
# 8           helpintroduction wikipedia
# 9  wikipediacommunity portal wikipedia
#
#                                                 text
# 0  wikipediawikipediathe free encyclopediaenglish...
# 1  wikipedia the free encyclopediajump to content...
# 2  wikipediacontents wikipediajump to contentmain...
# 3  portalcurrent events wikipediajump to contentm...
# 4  gulomahda wikipediajump to contentmain menumai...
# 5  wikipediaabout wikipediajump to contentmain me...
# 6  not foundpage not foundenwikipediaorgwikiwikip...
# 7  helpcontents wikipediajump to contentmain menu...
# ...

# %%
print(df['text'].str[:100])
# Out:
# 0    wikipediawikipediathe free encyclopediaenglish...
# 1    wikipedia the free encyclopediajump to content...
# 2    wikipediacontents wikipediajump to contentmain...
# 3    portalcurrent events wikipediajump to contentm...
# 4    gulomahda wikipediajump to contentmain menumai...
# 5    wikipediaabout wikipediajump to contentmain me...
# 6    not foundpage not foundenwikipediaorgwikiwikip...
# 7    helpcontents wikipediajump to contentmain menu...
# 8    helpintroduction wikipediajump to contentmain ...
# 9    wikipediacommunity portal wikipediajump to con...
# Name: text, dtype: object

# %% [markdown]
# ## Part 3: Downloading scripts

# %%
scripts=pd.read_csv('pudding_data.csv')

# %%
scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
#using the links in the "link" column, download the first 1000 characters of each script
#use requests and bs4, remember to remove all html tags

def get_scripts(url):
    try:
        source = requests.get(url)
        soup = bs4.BeautifulSoup(source.text)
        return clean(soup.get_text)[:1000]
    except:
        return None

scripts['script'] = scripts['link'].apply(get_scripts)

# %%
scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
#add a new column to the df with the text downloaded
#save this new dataframe as "pudding_texts.csv"
scripts.to_csv('pudding_texts.csv', index=False)

# %% [markdown]
# ## Part 4: TMDB database

# %% [markdown]
# #### Browse the documentation at https://developer.themoviedb.org/reference/intro/getting-started. Create an account to authenticate

# %%
#create a dataset of the movies in theaters now. Include metadata fields you are interested in. 
url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&language=en-US&api_key=23dc317cc7c25eed6f74efef918f11ce"
api_key = '23dc317cc7c25eed6f74efef918f11ce'
headers = {"accept": "application/python", "Authorization" : "Bearer" + api_key}

response = requests.get(url, headers=headers)

response.text
# Out:
# '{"page":1,"results":[{"adult":false,"backdrop_path":"/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg","genre_ids":[878,28,12],"id":912649,"original_language":"en","original_title":"Venom: The Last Dance","overview":"Eddie and Venom are on the run. Hunted by both of their worlds and with the net closing in, the duo are forced into a devastating decision that will bring the curtains down on Venom and Eddie\'s last dance.","popularity":6655.644,"poster_path":"/k42Owka8v91trK1qMYwCQCNwJKr.jpg","release_date":"2024-10-22","title":"Venom: The Last Dance","video":false,"vote_average":6.7,"vote_count":311},{"adult":false,"backdrop_path":"/v9acaWVVFdZT5yAU7J2QjwfhXyD.jpg","genre_ids":[16,878,10751],"id":1184918,"original_language":"en","original_title":"The Wild Robot","overview":"After a shipwreck, an intelligent robot called Roz is stranded on an uninhabited island. To survive the harsh environment, Roz bonds with the island\'s animals and cares for an orphaned baby goose.","popularity":5274.515,"poster_
# ...

# %%
dict = response.json()
movies = pd.DataFrame(dict['results'])
movies.head()
# Out:
#    adult                     backdrop_path                 genre_ids       id  \
# 0  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg             [878, 28, 12]   912649
# 1  False  /v9acaWVVFdZT5yAU7J2QjwfhXyD.jpg          [16, 878, 10751]  1184918
# 2  False  /xlkclSE4aq7r3JsFIJRgs21zUew.jpg                  [27, 53]  1034541
# 3  False  /oPUOpnl3pqD8wuidjfUn17mO1yA.jpg  [16, 878, 12, 10751, 28]   698687
# 4  False  /9SSEUrSqhljBMzRe4aBTh17rUaC.jpg                 [878, 27]   945961
#
#   original_language         original_title  \
# 0                en  Venom: The Last Dance
# 1                en         The Wild Robot
# 2                en            Terrifier 3
# 3                en       Transformers One
# 4                en         Alien: Romulus
#
#                                             overview  popularity  \
# 0  Eddie and Venom are on the run. Hunted by both...    6655.644
# 1  After a shipwreck, an intelligent robot called...    5274.515
# ...

# %%
#download the movie posters for 10 of these movies and save them to this repository
img_url = "https://image.tmdb.org/t/p/original" + movies['poster_path'][0]
img = requests.get(img_url)

# %%
for i in range(10):
    img_url = "https://image.tmdb.org/t/p/original" + movies['poster_path'][i]
    img = requests.get(img_url)
    with open(f'movie{i}.jpg', 'wb') as f:
        f.write(img.content)
